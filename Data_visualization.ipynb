# %%
from matplotlib import pyplot as plt
from boutdata import collect
import torch
import lightning as L

import models
import dataloader
from torch.utils.data import DataLoader

# %%
path = "../Data/Data_Files/"

# %%
# # 1. Read data
# n = collect('n', path = path)
# n = n.squeeze()

# # #%% plot tætheden i sidste tidsskridt

# # fig, ax = plt.subplots()
# # ax.contourf(n[-1, :, :].T)

# %%
# print(n.shape)

# %%
# # 2. Put data in dataloader
# seq_length = 5
# X_seq, y_seq = dataloader.bout_array_to_sequences(n, sequence_length = seq_length) 

# batch_size = 8 
# dataset = dataloader.PlasmaDataset(X_seq, y_seq)
# train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
# # Model parameters
# in_neurons = seq_length  # Input neurons equals number of timesteps for your sequences
# hidden_neurons = 64      
# out_neurons = seq_length  
# # out_neurons = 1 


# modesSpace = 16  # No of wave patterns for spatial dimensions
# modesTime = 16  # No of wave patterns for time dimension

# time_padding = 1  # Padding for the convolution
# input_size = 4  # (1 for t, 1 for x, 1 for y) + 1

# learning_rate = 1e-4
# restart_at_epoch_n = 10  # Number of epochs before restarting the learning rate scheduler
# loss_function = 'MSE'  # Choose your desired loss function

# # Initialize the model
# model = models.FNOModel(in_neurons, hidden_neurons, out_neurons, modesSpace, modesTime, time_padding, input_size, learning_rate, restart_at_epoch_n, train_loader, loss_function)

# # Initialize and train with PyTorch Lightning
# trainer = L.Trainer(
#     max_epochs=100
# )

# # Train
# trainer.fit(model, train_loader)

# %%
batch_size = 8 
train_loader, val_loader, test_loader = dataloader.build_dataloader(
    seq_len=4,
    batch_size=batch_size,
    seed=12,
    spatial_resolution=512,
    normalize=True,
    dataset_name='Test',
)
# Out:
# mxsub = 8 mysub = 1 mz = 1024
#
# nxpe = 128, nype = 1, npes = 128
#
# Reading from 0: [0-9][0-0] -> [0-9][0-0]
#
# Reading from 1: [2-9][0-0] -> [10-17][0-0]
#
# Reading from 2: [2-9][0-0] -> [18-25][0-0]
#
# Reading from 3: [2-9][0-0] -> [26-33][0-0]
#
# Reading from 4: [2-9][0-0] -> [34-41][0-0]
#
# Reading from 5: [2-9][0-0] -> [42-49][0-0]
#
# Reading from 6: [2-9][0-0] -> [50-57][0-0]
#
# Reading from 7: [2-9][0-0] -> [58-65][0-0]
#
# Reading from 8: [2-9][0-0] -> [66-73][0-0]
#
# Reading from 9: [2-9][0-0] -> [74-81][0-0]
#
# Reading from 10: [2-9][0-0] -> [82-89][0-0]
#
# Reading from 11: [2-9][0-0] -> [90-97][0-0]
#
# Reading from 12: [2-9][0-0] -> [98-105][0-0]
#
# Reading from 13: [2-9][0-0] -> [106-113][0-0]
#
# Reading from 14: [2-9][0-0] -> [114-121][0-0]
#
# Reading from 15: [2-9][0-0] -> [122-129][0-0]
#
# Reading from 16: [2-9][0-0] -> [130-137][0-0]
#
# Reading from 17: [2-9][0-0] -> [138-145][0-0]
#
# Reading from 18: [2-9][0-0] -> [146-153][0-0]
#
# Reading from 19: [2-9][0-0] -> [154-161][0-0]
#
# Reading from 20: [2-9][0-0] -> [162-169][0-0]
#
# Reading from 21: [2-9][0-0] -> [170-177][0-0]
#
# Reading from 22: [2-9][0-0] -> [178-185][0-0]
#
# Reading from 23: [2-9][0-0] -> [186-193][0-0]
#
# Reading from 24: [2-9][0-0] -> [194-201][0-0]
#
# Reading from 25: [2-9][0-0] -> [202-209][0-0]
#
# Reading from 26: [2-9][0-0] -> [210-217][0-0]
#
# Reading from 27: [2-9][0-0] -> [218-225][0-0]
#
# Reading from 28: [2-9][0-0] -> [226-233][0-0]
#
# Reading from 29: [2-9][0-0] -> [234-241][0-0]
#
# Reading from 30: [2-9][0-0] -> [242-249][0-0]
#
# Reading from 31: [2-9][0-0] -> [250-257][0-0]
#
# Reading from 32: [2-9][0-0] -> [258-265][0-0]
#
# Reading from 33: [2-9][0-0] -> [266-273][0-0]
#
# Reading from 34: [2-9][0-0] -> [274-281][0-0]
#
# Reading from 35: [2-9][0-0] -> [282-289][0-0]
#
# Reading from 36: [2-9][0-0] -> [290-297][0-0]
#
# Reading from 37: [2-9][0-0] -> [298-305][0-0]
#
# Reading from 38: [2-9][0-0] -> [306-313][0-0]
#
# Reading from 39: [2-9][0-0] -> [314-321][0-0]
#
# Reading from 40: [2-9][0-0] -> [322-329][0-0]
#
# Reading from 41: [2-9][0-0] -> [330-337][0-0]
#
# Reading from 42: [2-9][0-0] -> [338-345][0-0]
#
# Reading from 43: [2-9][0-0] -> [346-353][0-0]
#
# Reading from 44: [2-9][0-0] -> [354-361][0-0]
#
# Reading from 45: [2-9][0-0] -> [362-369][0-0]
#
# Reading from 46: [2-9][0-0] -> [370-377][0-0]
#
# Reading from 47: [2-9][0-0] -> [378-385][0-0]
#
# Reading from 48: [2-9][0-0] -> [386-393][0-0]
#
# Reading from 49: [2-9][0-0] -> [394-401][0-0]
#
# Reading from 50: [2-9][0-0] -> [402-409][0-0]
#
# Reading from 51: [2-9][0-0] -> [410-417][0-0]
#
# Reading from 52: [2-9][0-0] -> [418-425][0-0]
#
# Reading from 53: [2-9][0-0] -> [426-433][0-0]
#
# Reading from 54: [2-9][0-0] -> [434-441][0-0]
#
# Reading from 55: [2-9][0-0] -> [442-449][0-0]
#
# Reading from 56: [2-9][0-0] -> [450-457][0-0]
#
# Reading from 57: [2-9][0-0] -> [458-465][0-0]
#
# Reading from 58: [2-9][0-0] -> [466-473][0-0]
#
# Reading from 59: [2-9][0-0] -> [474-481][0-0]
#
# Reading from 60: [2-9][0-0] -> [482-489][0-0]
#
# Reading from 61: [2-9][0-0] -> [490-497][0-0]
#
# Reading from 62: [2-9][0-0] -> [498-505][0-0]
#
# Reading from 63: [2-9][0-0] -> [506-513][0-0]
#
# Reading from 64: [2-9][0-0] -> [514-521][0-0]
#
# Reading from 65: [2-9][0-0] -> [522-529][0-0]
#
# Reading from 66: [2-9][0-0] -> [530-537][0-0]
#
# Reading from 67: [2-9][0-0] -> [538-545][0-0]
#
# Reading from 68: [2-9][0-0] -> [546-553][0-0]
#
# Reading from 69: [2-9][0-0] -> [554-561][0-0]
#
# Reading from 70: [2-9][0-0] -> [562-569][0-0]
#
# Reading from 71: [2-9][0-0] -> [570-577][0-0]
#
# Reading from 72: [2-9][0-0] -> [578-585][0-0]
#
# Reading from 73: [2-9][0-0] -> [586-593][0-0]
#
# Reading from 74: [2-9][0-0] -> [594-601][0-0]
#
# Reading from 75: [2-9][0-0] -> [602-609][0-0]
#
# Reading from 76: [2-9][0-0] -> [610-617][0-0]
#
# Reading from 77: [2-9][0-0] -> [618-625][0-0]
#
# Reading from 78: [2-9][0-0] -> [626-633][0-0]
#
# Reading from 79: [2-9][0-0] -> [634-641][0-0]
#
# Reading from 80: [2-9][0-0] -> [642-649][0-0]
#
# Reading from 81: [2-9][0-0] -> [650-657][0-0]
#
# Reading from 82: [2-9][0-0] -> [658-665][0-0]
#
# Reading from 83: [2-9][0-0] -> [666-673][0-0]
#
# Reading from 84: [2-9][0-0] -> [674-681][0-0]
#
# Reading from 85: [2-9][0-0] -> [682-689][0-0]
#
# Reading from 86: [2-9][0-0] -> [690-697][0-0]
#
# Reading from 87: [2-9][0-0] -> [698-705][0-0]
#
# Reading from 88: [2-9][0-0] -> [706-713][0-0]
#
# Reading from 89: [2-9][0-0] -> [714-721][0-0]
#
# Reading from 90: [2-9][0-0] -> [722-729][0-0]
#
# Reading from 91: [2-9][0-0] -> [730-737][0-0]
#
# Reading from 92: [2-9][0-0] -> [738-745][0-0]
#
# Reading from 93: [2-9][0-0] -> [746-753][0-0]
#
# Reading from 94: [2-9][0-0] -> [754-761][0-0]
#
# Reading from 95: [2-9][0-0] -> [762-769][0-0]
#
# Reading from 96: [2-9][0-0] -> [770-777][0-0]
#
# Reading from 97: [2-9][0-0] -> [778-785][0-0]
#
# Reading from 98: [2-9][0-0] -> [786-793][0-0]
#
# Reading from 99: [2-9][0-0] -> [794-801][0-0]
#
# Reading from 100: [2-9][0-0] -> [802-809][0-0]
#
# Reading from 101: [2-9][0-0] -> [810-817][0-0]
#
# Reading from 102: [2-9][0-0] -> [818-825][0-0]
#
# Reading from 103: [2-9][0-0] -> [826-833][0-0]
#
# Reading from 104: [2-9][0-0] -> [834-841][0-0]
#
# Reading from 105: [2-9][0-0] -> [842-849][0-0]
#
# Reading from 106: [2-9][0-0] -> [850-857][0-0]
#
# Reading from 107: [2-9][0-0] -> [858-865][0-0]
#
# Reading from 108: [2-9][0-0] -> [866-873][0-0]
#
# Reading from 109: [2-9][0-0] -> [874-881][0-0]
#
# Reading from 110: [2-9][0-0] -> [882-889][0-0]
#
# Reading from 111: [2-9][0-0] -> [890-897][0-0]
#
# Reading from 112: [2-9][0-0] -> [898-905][0-0]
#
# Reading from 113: [2-9][0-0] -> [906-913][0-0]
#
# Reading from 114: [2-9][0-0] -> [914-921][0-0]
#
# Reading from 115: [2-9][0-0] -> [922-929][0-0]
#
# Reading from 116: [2-9][0-0] -> [930-937][0-0]
#
# Reading from 117: [2-9][0-0] -> [938-945][0-0]
#
# Reading from 118: [2-9][0-0] -> [946-953][0-0]
#
# Reading from 119: [2-9][0-0] -> [954-961][0-0]
#
# Reading from 120: [2-9][0-0] -> [962-969][0-0]
#
# Reading from 121: [2-9][0-0] -> [970-977][0-0]
#
# Reading from 122: [2-9][0-0] -> [978-985][0-0]
#
# Reading from 123: [2-9][0-0] -> [986-993][0-0]
#
# Reading from 124: [2-9][0-0] -> [994-1001][0-0]
#
# Reading from 125: [2-9][0-0] -> [1002-1009][0-0]
#
# Reading from 126: [2-9][0-0] -> [1010-1017][0-0]
#
# Reading from 127: [2-11][0-0] -> [1018-1027][0-0]
#
#
# mxsub = 8 mysub = 1 mz = 1024
#
# nxpe = 128, nype = 1, npes = 128
#
# Reading from 0: [0-9][0-0] -> [0-9][0-0]
#
# Reading from 1: [2-9][0-0] -> [10-17][0-0]
#
# Reading from 2: [2-9][0-0] -> [18-25][0-0]
#
# Reading from 3: [2-9][0-0] -> [26-33][0-0]
#
# Reading from 4: [2-9][0-0] -> [34-41][0-0]
#
# Reading from 5: [2-9][0-0] -> [42-49][0-0]
#
# Reading from 6: [2-9][0-0] -> [50-57][0-0]
#
# Reading from 7: [2-9][0-0] -> [58-65][0-0]
#
# Reading from 8: [2-9][0-0] -> [66-73][0-0]
#
# Reading from 9: [2-9][0-0] -> [74-81][0-0]
#
# Reading from 10: [2-9][0-0] -> [82-89][0-0]
#
# Reading from 11: [2-9][0-0] -> [90-97][0-0]
#
# Reading from 12: [2-9][0-0] -> [98-105][0-0]
#
# Reading from 13: [2-9][0-0] -> [106-113][0-0]
#
# Reading from 14: [2-9][0-0] -> [114-121][0-0]
#
# Reading from 15: [2-9][0-0] -> [122-129][0-0]
#
# Reading from 16: [2-9][0-0] -> [130-137][0-0]
#
# Reading from 17: [2-9][0-0] -> [138-145][0-0]
#
# Reading from 18: [2-9][0-0] -> [146-153][0-0]
#
# Reading from 19: [2-9][0-0] -> [154-161][0-0]
#
# Reading from 20: [2-9][0-0] -> [162-169][0-0]
#
# Reading from 21: [2-9][0-0] -> [170-177][0-0]
#
# Reading from 22: [2-9][0-0] -> [178-185][0-0]
#
# Reading from 23: [2-9][0-0] -> [186-193][0-0]
#
# Reading from 24: [2-9][0-0] -> [194-201][0-0]
#
# Reading from 25: [2-9][0-0] -> [202-209][0-0]
#
# Reading from 26: [2-9][0-0] -> [210-217][0-0]
#
# Reading from 27: [2-9][0-0] -> [218-225][0-0]
#
# Reading from 28: [2-9][0-0] -> [226-233][0-0]
#
# Reading from 29: [2-9][0-0] -> [234-241][0-0]
#
# Reading from 30: [2-9][0-0] -> [242-249][0-0]
#
# Reading from 31: [2-9][0-0] -> [250-257][0-0]
#
# Reading from 32: [2-9][0-0] -> [258-265][0-0]
#
# Reading from 33: [2-9][0-0] -> [266-273][0-0]
#
# Reading from 34: [2-9][0-0] -> [274-281][0-0]
#
# Reading from 35: [2-9][0-0] -> [282-289][0-0]
#
# Reading from 36: [2-9][0-0] -> [290-297][0-0]
#
# Reading from 37: [2-9][0-0] -> [298-305][0-0]
#
# Reading from 38: [2-9][0-0] -> [306-313][0-0]
#
# Reading from 39: [2-9][0-0] -> [314-321][0-0]
#
# Reading from 40: [2-9][0-0] -> [322-329][0-0]
#
# Reading from 41: [2-9][0-0] -> [330-337][0-0]
#
# Reading from 42: [2-9][0-0] -> [338-345][0-0]
#
# Reading from 43: [2-9][0-0] -> [346-353][0-0]
#
# Reading from 44: [2-9][0-0] -> [354-361][0-0]
#
# Reading from 45: [2-9][0-0] -> [362-369][0-0]
#
# Reading from 46: [2-9][0-0] -> [370-377][0-0]
#
# Reading from 47: [2-9][0-0] -> [378-385][0-0]
#
# Reading from 48: [2-9][0-0] -> [386-393][0-0]
#
# Reading from 49: [2-9][0-0] -> [394-401][0-0]
#
# Reading from 50: [2-9][0-0] -> [402-409][0-0]
#
# Reading from 51: [2-9][0-0] -> [410-417][0-0]
#
# Reading from 52: [2-9][0-0] -> [418-425][0-0]
#
# Reading from 53: [2-9][0-0] -> [426-433][0-0]
#
# Reading from 54: [2-9][0-0] -> [434-441][0-0]
#
# Reading from 55: [2-9][0-0] -> [442-449][0-0]
#
# Reading from 56: [2-9][0-0] -> [450-457][0-0]
#
# Reading from 57: [2-9][0-0] -> [458-465][0-0]
#
# Reading from 58: [2-9][0-0] -> [466-473][0-0]
#
# Reading from 59: [2-9][0-0] -> [474-481][0-0]
#
# Reading from 60: [2-9][0-0] -> [482-489][0-0]
#
# Reading from 61: [2-9][0-0] -> [490-497][0-0]
#
# Reading from 62: [2-9][0-0] -> [498-505][0-0]
#
# Reading from 63: [2-9][0-0] -> [506-513][0-0]
#
# Reading from 64: [2-9][0-0] -> [514-521][0-0]
#
# Reading from 65: [2-9][0-0] -> [522-529][0-0]
#
# Reading from 66: [2-9][0-0] -> [530-537][0-0]
#
# Reading from 67: [2-9][0-0] -> [538-545][0-0]
#
# Reading from 68: [2-9][0-0] -> [546-553][0-0]
#
# Reading from 69: [2-9][0-0] -> [554-561][0-0]
#
# Reading from 70: [2-9][0-0] -> [562-569][0-0]
#
# Reading from 71: [2-9][0-0] -> [570-577][0-0]
#
# Reading from 72: [2-9][0-0] -> [578-585][0-0]
#
# Reading from 73: [2-9][0-0] -> [586-593][0-0]
#
# Reading from 74: [2-9][0-0] -> [594-601][0-0]
#
# Reading from 75: [2-9][0-0] -> [602-609][0-0]
#
# Reading from 76: [2-9][0-0] -> [610-617][0-0]
#
# Reading from 77: [2-9][0-0] -> [618-625][0-0]
#
# Reading from 78: [2-9][0-0] -> [626-633][0-0]
#
# Reading from 79: [2-9][0-0] -> [634-641][0-0]
#
# Reading from 80: [2-9][0-0] -> [642-649][0-0]
#
# Reading from 81: [2-9][0-0] -> [650-657][0-0]
#
# Reading from 82: [2-9][0-0] -> [658-665][0-0]
#
# Reading from 83: [2-9][0-0] -> [666-673][0-0]
#
# Reading from 84: [2-9][0-0] -> [674-681][0-0]
#
# Reading from 85: [2-9][0-0] -> [682-689][0-0]
#
# Reading from 86: [2-9][0-0] -> [690-697][0-0]
#
# Reading from 87: [2-9][0-0] -> [698-705][0-0]
#
# Reading from 88: [2-9][0-0] -> [706-713][0-0]
#
# Reading from 89: [2-9][0-0] -> [714-721][0-0]
#
# Reading from 90: [2-9][0-0] -> [722-729][0-0]
#
# Reading from 91: [2-9][0-0] -> [730-737][0-0]
#
# Reading from 92: [2-9][0-0] -> [738-745][0-0]
#
# Reading from 93: [2-9][0-0] -> [746-753][0-0]
#
# Reading from 94: [2-9][0-0] -> [754-761][0-0]
#
# Reading from 95: [2-9][0-0] -> [762-769][0-0]
#
# Reading from 96: [2-9][0-0] -> [770-777][0-0]
#
# Reading from 97: [2-9][0-0] -> [778-785][0-0]
#
# Reading from 98: [2-9][0-0] -> [786-793][0-0]
#
# Reading from 99: [2-9][0-0] -> [794-801][0-0]
#
# Reading from 100: [2-9][0-0] -> [802-809][0-0]
#
# Reading from 101: [2-9][0-0] -> [810-817][0-0]
#
# Reading from 102: [2-9][0-0] -> [818-825][0-0]
#
# Reading from 103: [2-9][0-0] -> [826-833][0-0]
#
# Reading from 104: [2-9][0-0] -> [834-841][0-0]
#
# Reading from 105: [2-9][0-0] -> [842-849][0-0]
#
# Reading from 106: [2-9][0-0] -> [850-857][0-0]
#
# Reading from 107: [2-9][0-0] -> [858-865][0-0]
#
# Reading from 108: [2-9][0-0] -> [866-873][0-0]
#
# Reading from 109: [2-9][0-0] -> [874-881][0-0]
#
# Reading from 110: [2-9][0-0] -> [882-889][0-0]
#
# Reading from 111: [2-9][0-0] -> [890-897][0-0]
#
# Reading from 112: [2-9][0-0] -> [898-905][0-0]
#
# Reading from 113: [2-9][0-0] -> [906-913][0-0]
#
# Reading from 114: [2-9][0-0] -> [914-921][0-0]
#
# Reading from 115: [2-9][0-0] -> [922-929][0-0]
#
# Reading from 116: [2-9][0-0] -> [930-937][0-0]
#
# Reading from 117: [2-9][0-0] -> [938-945][0-0]
#
# Reading from 118: [2-9][0-0] -> [946-953][0-0]
#
# Reading from 119: [2-9][0-0] -> [954-961][0-0]
#
# Reading from 120: [2-9][0-0] -> [962-969][0-0]
#
# Reading from 121: [2-9][0-0] -> [970-977][0-0]
#
# Reading from 122: [2-9][0-0] -> [978-985][0-0]
#
# Reading from 123: [2-9][0-0] -> [986-993][0-0]
#
# Reading from 124: [2-9][0-0] -> [994-1001][0-0]
#
# Reading from 125: [2-9][0-0] -> [1002-1009][0-0]
#
# Reading from 126: [2-9][0-0] -> [1010-1017][0-0]
#
# Reading from 127: [2-11][0-0] -> [1018-1027][0-0]
#
#
# Data loaded: Original size, target resolution: 512, normalization=on

# %%
x_Train, y_train = next(iter(train_loader))  # Get one batch from the DataLoader
x_Train.shape
# Out:
# torch.Size([8, 2, 512, 512])

# %%
for i in range(2):
    fig, ax = plt.subplots()
    ax.contourf(x_Train[0, i, :, :].T)

# %%
for i in range(2):
    fig, ax = plt.subplots()
    ax.contourf(y_train[0, i, :, :].T)

# %%
batch_size = 8 
train_loader, val_loader, test_loader = dataloader.build_dataloader(
    seq_len=4,
    batch_size=batch_size,
    seed=12,
    spatial_resolution=512,
    normalize=True,
    dataset_name='Test',
    noise_std = (0.0,0.05)
)
# Out:
# mxsub = 8 mysub = 1 mz = 1024
#
# nxpe = 128, nype = 1, npes = 128
#
# Reading from 0: [0-9][0-0] -> [0-9][0-0]
#
# Reading from 1: [2-9][0-0] -> [10-17][0-0]
#
# Reading from 2: [2-9][0-0] -> [18-25][0-0]
#
# Reading from 3: [2-9][0-0] -> [26-33][0-0]
#
# Reading from 4: [2-9][0-0] -> [34-41][0-0]
#
# Reading from 5: [2-9][0-0] -> [42-49][0-0]
#
# Reading from 6: [2-9][0-0] -> [50-57][0-0]
#
# Reading from 7: [2-9][0-0] -> [58-65][0-0]
#
# Reading from 8: [2-9][0-0] -> [66-73][0-0]
#
# Reading from 9: [2-9][0-0] -> [74-81][0-0]
#
# Reading from 10: [2-9][0-0] -> [82-89][0-0]
#
# Reading from 11: [2-9][0-0] -> [90-97][0-0]
#
# Reading from 12: [2-9][0-0] -> [98-105][0-0]
#
# Reading from 13: [2-9][0-0] -> [106-113][0-0]
#
# Reading from 14: [2-9][0-0] -> [114-121][0-0]
#
# Reading from 15: [2-9][0-0] -> [122-129][0-0]
#
# Reading from 16: [2-9][0-0] -> [130-137][0-0]
#
# Reading from 17: [2-9][0-0] -> [138-145][0-0]
#
# Reading from 18: [2-9][0-0] -> [146-153][0-0]
#
# Reading from 19: [2-9][0-0] -> [154-161][0-0]
#
# Reading from 20: [2-9][0-0] -> [162-169][0-0]
#
# Reading from 21: [2-9][0-0] -> [170-177][0-0]
#
# Reading from 22: [2-9][0-0] -> [178-185][0-0]
#
# Reading from 23: [2-9][0-0] -> [186-193][0-0]
#
# Reading from 24: [2-9][0-0] -> [194-201][0-0]
#
# Reading from 25: [2-9][0-0] -> [202-209][0-0]
#
# Reading from 26: [2-9][0-0] -> [210-217][0-0]
#
# Reading from 27: [2-9][0-0] -> [218-225][0-0]
#
# Reading from 28: [2-9][0-0] -> [226-233][0-0]
#
# Reading from 29: [2-9][0-0] -> [234-241][0-0]
#
# Reading from 30: [2-9][0-0] -> [242-249][0-0]
#
# Reading from 31: [2-9][0-0] -> [250-257][0-0]
#
# Reading from 32: [2-9][0-0] -> [258-265][0-0]
#
# Reading from 33: [2-9][0-0] -> [266-273][0-0]
#
# Reading from 34: [2-9][0-0] -> [274-281][0-0]
#
# Reading from 35: [2-9][0-0] -> [282-289][0-0]
#
# Reading from 36: [2-9][0-0] -> [290-297][0-0]
#
# Reading from 37: [2-9][0-0] -> [298-305][0-0]
#
# Reading from 38: [2-9][0-0] -> [306-313][0-0]
#
# Reading from 39: [2-9][0-0] -> [314-321][0-0]
#
# Reading from 40: [2-9][0-0] -> [322-329][0-0]
#
# Reading from 41: [2-9][0-0] -> [330-337][0-0]
#
# Reading from 42: [2-9][0-0] -> [338-345][0-0]
#
# Reading from 43: [2-9][0-0] -> [346-353][0-0]
#
# Reading from 44: [2-9][0-0] -> [354-361][0-0]
#
# Reading from 45: [2-9][0-0] -> [362-369][0-0]
#
# Reading from 46: [2-9][0-0] -> [370-377][0-0]
#
# Reading from 47: [2-9][0-0] -> [378-385][0-0]
#
# Reading from 48: [2-9][0-0] -> [386-393][0-0]
#
# Reading from 49: [2-9][0-0] -> [394-401][0-0]
#
# Reading from 50: [2-9][0-0] -> [402-409][0-0]
#
# Reading from 51: [2-9][0-0] -> [410-417][0-0]
#
# Reading from 52: [2-9][0-0] -> [418-425][0-0]
#
# Reading from 53: [2-9][0-0] -> [426-433][0-0]
#
# Reading from 54: [2-9][0-0] -> [434-441][0-0]
#
# Reading from 55: [2-9][0-0] -> [442-449][0-0]
#
# Reading from 56: [2-9][0-0] -> [450-457][0-0]
#
# Reading from 57: [2-9][0-0] -> [458-465][0-0]
#
# Reading from 58: [2-9][0-0] -> [466-473][0-0]
#
# Reading from 59: [2-9][0-0] -> [474-481][0-0]
#
# Reading from 60: [2-9][0-0] -> [482-489][0-0]
#
# Reading from 61: [2-9][0-0] -> [490-497][0-0]
#
# Reading from 62: [2-9][0-0] -> [498-505][0-0]
#
# Reading from 63: [2-9][0-0] -> [506-513][0-0]
#
# Reading from 64: [2-9][0-0] -> [514-521][0-0]
#
# Reading from 65: [2-9][0-0] -> [522-529][0-0]
#
# Reading from 66: [2-9][0-0] -> [530-537][0-0]
#
# Reading from 67: [2-9][0-0] -> [538-545][0-0]
#
# Reading from 68: [2-9][0-0] -> [546-553][0-0]
#
# Reading from 69: [2-9][0-0] -> [554-561][0-0]
#
# Reading from 70: [2-9][0-0] -> [562-569][0-0]
#
# Reading from 71: [2-9][0-0] -> [570-577][0-0]
#
# Reading from 72: [2-9][0-0] -> [578-585][0-0]
#
# Reading from 73: [2-9][0-0] -> [586-593][0-0]
#
# Reading from 74: [2-9][0-0] -> [594-601][0-0]
#
# Reading from 75: [2-9][0-0] -> [602-609][0-0]
#
# Reading from 76: [2-9][0-0] -> [610-617][0-0]
#
# Reading from 77: [2-9][0-0] -> [618-625][0-0]
#
# Reading from 78: [2-9][0-0] -> [626-633][0-0]
#
# Reading from 79: [2-9][0-0] -> [634-641][0-0]
#
# Reading from 80: [2-9][0-0] -> [642-649][0-0]
#
# Reading from 81: [2-9][0-0] -> [650-657][0-0]
#
# Reading from 82: [2-9][0-0] -> [658-665][0-0]
#
# Reading from 83: [2-9][0-0] -> [666-673][0-0]
#
# Reading from 84: [2-9][0-0] -> [674-681][0-0]
#
# Reading from 85: [2-9][0-0] -> [682-689][0-0]
#
# Reading from 86: [2-9][0-0] -> [690-697][0-0]
#
# Reading from 87: [2-9][0-0] -> [698-705][0-0]
#
# Reading from 88: [2-9][0-0] -> [706-713][0-0]
#
# Reading from 89: [2-9][0-0] -> [714-721][0-0]
#
# Reading from 90: [2-9][0-0] -> [722-729][0-0]
#
# Reading from 91: [2-9][0-0] -> [730-737][0-0]
#
# Reading from 92: [2-9][0-0] -> [738-745][0-0]
#
# Reading from 93: [2-9][0-0] -> [746-753][0-0]
#
# Reading from 94: [2-9][0-0] -> [754-761][0-0]
#
# Reading from 95: [2-9][0-0] -> [762-769][0-0]
#
# Reading from 96: [2-9][0-0] -> [770-777][0-0]
#
# Reading from 97: [2-9][0-0] -> [778-785][0-0]
#
# Reading from 98: [2-9][0-0] -> [786-793][0-0]
#
# Reading from 99: [2-9][0-0] -> [794-801][0-0]
#
# Reading from 100: [2-9][0-0] -> [802-809][0-0]
#
# Reading from 101: [2-9][0-0] -> [810-817][0-0]
#
# Reading from 102: [2-9][0-0] -> [818-825][0-0]
#
# Reading from 103: [2-9][0-0] -> [826-833][0-0]
#
# Reading from 104: [2-9][0-0] -> [834-841][0-0]
#
# Reading from 105: [2-9][0-0] -> [842-849][0-0]
#
# Reading from 106: [2-9][0-0] -> [850-857][0-0]
#
# Reading from 107: [2-9][0-0] -> [858-865][0-0]
#
# Reading from 108: [2-9][0-0] -> [866-873][0-0]
#
# Reading from 109: [2-9][0-0] -> [874-881][0-0]
#
# Reading from 110: [2-9][0-0] -> [882-889][0-0]
#
# Reading from 111: [2-9][0-0] -> [890-897][0-0]
#
# Reading from 112: [2-9][0-0] -> [898-905][0-0]
#
# Reading from 113: [2-9][0-0] -> [906-913][0-0]
#
# Reading from 114: [2-9][0-0] -> [914-921][0-0]
#
# Reading from 115: [2-9][0-0] -> [922-929][0-0]
#
# Reading from 116: [2-9][0-0] -> [930-937][0-0]
#
# Reading from 117: [2-9][0-0] -> [938-945][0-0]
#
# Reading from 118: [2-9][0-0] -> [946-953][0-0]
#
# Reading from 119: [2-9][0-0] -> [954-961][0-0]
#
# Reading from 120: [2-9][0-0] -> [962-969][0-0]
#
# Reading from 121: [2-9][0-0] -> [970-977][0-0]
#
# Reading from 122: [2-9][0-0] -> [978-985][0-0]
#
# Reading from 123: [2-9][0-0] -> [986-993][0-0]
#
# Reading from 124: [2-9][0-0] -> [994-1001][0-0]
#
# Reading from 125: [2-9][0-0] -> [1002-1009][0-0]
#
# Reading from 126: [2-9][0-0] -> [1010-1017][0-0]
#
# Reading from 127: [2-11][0-0] -> [1018-1027][0-0]
#
#
# mxsub = 8 mysub = 1 mz = 1024
#
# nxpe = 128, nype = 1, npes = 128
#
# Reading from 0: [0-9][0-0] -> [0-9][0-0]
#
# Reading from 1: [2-9][0-0] -> [10-17][0-0]
#
# Reading from 2: [2-9][0-0] -> [18-25][0-0]
#
# Reading from 3: [2-9][0-0] -> [26-33][0-0]
#
# Reading from 4: [2-9][0-0] -> [34-41][0-0]
#
# Reading from 5: [2-9][0-0] -> [42-49][0-0]
#
# Reading from 6: [2-9][0-0] -> [50-57][0-0]
#
# Reading from 7: [2-9][0-0] -> [58-65][0-0]
#
# Reading from 8: [2-9][0-0] -> [66-73][0-0]
#
# Reading from 9: [2-9][0-0] -> [74-81][0-0]
#
# Reading from 10: [2-9][0-0] -> [82-89][0-0]
#
# Reading from 11: [2-9][0-0] -> [90-97][0-0]
#
# Reading from 12: [2-9][0-0] -> [98-105][0-0]
#
# Reading from 13: [2-9][0-0] -> [106-113][0-0]
#
# Reading from 14: [2-9][0-0] -> [114-121][0-0]
#
# Reading from 15: [2-9][0-0] -> [122-129][0-0]
#
# Reading from 16: [2-9][0-0] -> [130-137][0-0]
#
# Reading from 17: [2-9][0-0] -> [138-145][0-0]
#
# Reading from 18: [2-9][0-0] -> [146-153][0-0]
#
# Reading from 19: [2-9][0-0] -> [154-161][0-0]
#
# Reading from 20: [2-9][0-0] -> [162-169][0-0]
#
# Reading from 21: [2-9][0-0] -> [170-177][0-0]
#
# Reading from 22: [2-9][0-0] -> [178-185][0-0]
#
# Reading from 23: [2-9][0-0] -> [186-193][0-0]
#
# Reading from 24: [2-9][0-0] -> [194-201][0-0]
#
# Reading from 25: [2-9][0-0] -> [202-209][0-0]
#
# Reading from 26: [2-9][0-0] -> [210-217][0-0]
#
# Reading from 27: [2-9][0-0] -> [218-225][0-0]
#
# Reading from 28: [2-9][0-0] -> [226-233][0-0]
#
# Reading from 29: [2-9][0-0] -> [234-241][0-0]
#
# Reading from 30: [2-9][0-0] -> [242-249][0-0]
#
# Reading from 31: [2-9][0-0] -> [250-257][0-0]
#
# Reading from 32: [2-9][0-0] -> [258-265][0-0]
#
# Reading from 33: [2-9][0-0] -> [266-273][0-0]
#
# Reading from 34: [2-9][0-0] -> [274-281][0-0]
#
# Reading from 35: [2-9][0-0] -> [282-289][0-0]
#
# Reading from 36: [2-9][0-0] -> [290-297][0-0]
#
# Reading from 37: [2-9][0-0] -> [298-305][0-0]
#
# Reading from 38: [2-9][0-0] -> [306-313][0-0]
#
# Reading from 39: [2-9][0-0] -> [314-321][0-0]
#
# Reading from 40: [2-9][0-0] -> [322-329][0-0]
#
# Reading from 41: [2-9][0-0] -> [330-337][0-0]
#
# Reading from 42: [2-9][0-0] -> [338-345][0-0]
#
# Reading from 43: [2-9][0-0] -> [346-353][0-0]
#
# Reading from 44: [2-9][0-0] -> [354-361][0-0]
#
# Reading from 45: [2-9][0-0] -> [362-369][0-0]
#
# Reading from 46: [2-9][0-0] -> [370-377][0-0]
#
# Reading from 47: [2-9][0-0] -> [378-385][0-0]
#
# Reading from 48: [2-9][0-0] -> [386-393][0-0]
#
# Reading from 49: [2-9][0-0] -> [394-401][0-0]
#
# Reading from 50: [2-9][0-0] -> [402-409][0-0]
#
# Reading from 51: [2-9][0-0] -> [410-417][0-0]
#
# Reading from 52: [2-9][0-0] -> [418-425][0-0]
#
# Reading from 53: [2-9][0-0] -> [426-433][0-0]
#
# Reading from 54: [2-9][0-0] -> [434-441][0-0]
#
# Reading from 55: [2-9][0-0] -> [442-449][0-0]
#
# Reading from 56: [2-9][0-0] -> [450-457][0-0]
#
# Reading from 57: [2-9][0-0] -> [458-465][0-0]
#
# Reading from 58: [2-9][0-0] -> [466-473][0-0]
#
# Reading from 59: [2-9][0-0] -> [474-481][0-0]
#
# Reading from 60: [2-9][0-0] -> [482-489][0-0]
#
# Reading from 61: [2-9][0-0] -> [490-497][0-0]
#
# Reading from 62: [2-9][0-0] -> [498-505][0-0]
#
# Reading from 63: [2-9][0-0] -> [506-513][0-0]
#
# Reading from 64: [2-9][0-0] -> [514-521][0-0]
#
# Reading from 65: [2-9][0-0] -> [522-529][0-0]
#
# Reading from 66: [2-9][0-0] -> [530-537][0-0]
#
# Reading from 67: [2-9][0-0] -> [538-545][0-0]
#
# Reading from 68: [2-9][0-0] -> [546-553][0-0]
#
# Reading from 69: [2-9][0-0] -> [554-561][0-0]
#
# Reading from 70: [2-9][0-0] -> [562-569][0-0]
#
# Reading from 71: [2-9][0-0] -> [570-577][0-0]
#
# Reading from 72: [2-9][0-0] -> [578-585][0-0]
#
# Reading from 73: [2-9][0-0] -> [586-593][0-0]
#
# Reading from 74: [2-9][0-0] -> [594-601][0-0]
#
# Reading from 75: [2-9][0-0] -> [602-609][0-0]
#
# Reading from 76: [2-9][0-0] -> [610-617][0-0]
#
# Reading from 77: [2-9][0-0] -> [618-625][0-0]
#
# Reading from 78: [2-9][0-0] -> [626-633][0-0]
#
# Reading from 79: [2-9][0-0] -> [634-641][0-0]
#
# Reading from 80: [2-9][0-0] -> [642-649][0-0]
#
# Reading from 81: [2-9][0-0] -> [650-657][0-0]
#
# Reading from 82: [2-9][0-0] -> [658-665][0-0]
#
# Reading from 83: [2-9][0-0] -> [666-673][0-0]
#
# Reading from 84: [2-9][0-0] -> [674-681][0-0]
#
# Reading from 85: [2-9][0-0] -> [682-689][0-0]
#
# Reading from 86: [2-9][0-0] -> [690-697][0-0]
#
# Reading from 87: [2-9][0-0] -> [698-705][0-0]
#
# Reading from 88: [2-9][0-0] -> [706-713][0-0]
#
# Reading from 89: [2-9][0-0] -> [714-721][0-0]
#
# Reading from 90: [2-9][0-0] -> [722-729][0-0]
#
# Reading from 91: [2-9][0-0] -> [730-737][0-0]
#
# Reading from 92: [2-9][0-0] -> [738-745][0-0]
#
# Reading from 93: [2-9][0-0] -> [746-753][0-0]
#
# Reading from 94: [2-9][0-0] -> [754-761][0-0]
#
# Reading from 95: [2-9][0-0] -> [762-769][0-0]
#
# Reading from 96: [2-9][0-0] -> [770-777][0-0]
#
# Reading from 97: [2-9][0-0] -> [778-785][0-0]
#
# Reading from 98: [2-9][0-0] -> [786-793][0-0]
#
# Reading from 99: [2-9][0-0] -> [794-801][0-0]
#
# Reading from 100: [2-9][0-0] -> [802-809][0-0]
#
# Reading from 101: [2-9][0-0] -> [810-817][0-0]
#
# Reading from 102: [2-9][0-0] -> [818-825][0-0]
#
# Reading from 103: [2-9][0-0] -> [826-833][0-0]
#
# Reading from 104: [2-9][0-0] -> [834-841][0-0]
#
# Reading from 105: [2-9][0-0] -> [842-849][0-0]
#
# Reading from 106: [2-9][0-0] -> [850-857][0-0]
#
# Reading from 107: [2-9][0-0] -> [858-865][0-0]
#
# Reading from 108: [2-9][0-0] -> [866-873][0-0]
#
# Reading from 109: [2-9][0-0] -> [874-881][0-0]
#
# Reading from 110: [2-9][0-0] -> [882-889][0-0]
#
# Reading from 111: [2-9][0-0] -> [890-897][0-0]
#
# Reading from 112: [2-9][0-0] -> [898-905][0-0]
#
# Reading from 113: [2-9][0-0] -> [906-913][0-0]
#
# Reading from 114: [2-9][0-0] -> [914-921][0-0]
#
# Reading from 115: [2-9][0-0] -> [922-929][0-0]
#
# Reading from 116: [2-9][0-0] -> [930-937][0-0]
#
# Reading from 117: [2-9][0-0] -> [938-945][0-0]
#
# Reading from 118: [2-9][0-0] -> [946-953][0-0]
#
# Reading from 119: [2-9][0-0] -> [954-961][0-0]
#
# Reading from 120: [2-9][0-0] -> [962-969][0-0]
#
# Reading from 121: [2-9][0-0] -> [970-977][0-0]
#
# Reading from 122: [2-9][0-0] -> [978-985][0-0]
#
# Reading from 123: [2-9][0-0] -> [986-993][0-0]
#
# Reading from 124: [2-9][0-0] -> [994-1001][0-0]
#
# Reading from 125: [2-9][0-0] -> [1002-1009][0-0]
#
# Reading from 126: [2-9][0-0] -> [1010-1017][0-0]
#
# Reading from 127: [2-11][0-0] -> [1018-1027][0-0]
#
#
# Data loaded: Original size, target resolution: 512, normalization=on

# %%
x_Train, y_train = next(iter(train_loader))  # Get one batch from the DataLoader
x_Train.shape
# Out:
# torch.Size([8, 2, 512, 512])

# %%
for i in range(2):
    fig, ax = plt.subplots()
    ax.contourf(x_Train[1, i, :, :].T)

# %%
for i in range(2):
    fig, ax = plt.subplots()
    ax.contourf(y_train[1, i, :, :].T)
